# %%
! python nanoGPT/data/shakespeare_char/prepare.py
# Out:
# length of dataset in characters: 5,718,328
# all the unique characters:
#  !"%&'()*+,-./0123456789:;=?ABCDEFGHIJKLMNOPQRSTUVWXYZ^_`abcdefghijklmnopqrstuvwxyz°ÀÁÂÃÉÊÌÍÐÒÓÔÙÚÝàáâãèéêìíîòóôõùúûýĀĂăĐđĩŨũƠơƯư̕өߠẠạẢảẤấẦầẩẪẫẬậẮắẰằẲẳẵẶặẸẹẻẽẾếỀềỂểễỆệỈỉỊịỌọỎỏỐốỒồỔổỗỘộỚớỜờỞởỠỡỢợụỦủỨứỪừỬửỮữựỳỵỷỹ–‘’“”„†•㍊㰠
# vocab size: 221
# train has 5,146,495 tokens
# val has 571,833 tokens

# %%
! cd nanoGPT && python train.py config/train_shakespeare_char.py
# Out:
# Overriding config with config/train_shakespeare_char.py:
# # train a miniature character-level shakespeare model
# # good for debugging and playing on macbooks and such
#
# out_dir = 'out-shakespeare-char'
# eval_interval = 250 # keep frequent because we'll overfit
# eval_iters = 200
# log_interval = 10 # don't print too too often
#
# # we expect to overfit on this small dataset, so only save when val improves
# always_save_checkpoint = False
#
# wandb_log = False # override via command line if you like
# wandb_project = 'shakespeare-char'
# wandb_run_name = 'mini-gpt'
#
# dataset = 'shakespeare_char'
# gradient_accumulation_steps = 1
# batch_size = 128
# block_size = 512 # context of up to 256 previous characters
#
# # baby GPT model :)
# n_layer = 6
# n_head = 6
# n_embd = 516
# dropout = 0.2
#
# learning_rate = 1e-3 # with baby networks can afford to go a bit higher
# max_iters = 5000
# lr_decay_iters = 5000 # make equal to max_iters usually
# min_lr = 1e-4 # learning_rate / 10 usually
# beta2 = 0.99 # make a bit bigger because number of tokens per iter is small
#
# warmup_iters = 100 # not super necessary potentially
#
# # on macbook also add
# # device = 'cpu'  # run on cpu only
# # compile = False # do not torch compile the model
#
# tokens per iteration will be: 65,536
# found vocab_size = 221 (inside data/shakespeare_char/meta.pkl)
# Initializing a new model from scratch
# number of parameters: 19.29M
# num decayed parameter tensors: 26, with 19,548,660 parameters
# num non-decayed parameter tensors: 13, with 6,708 parameters
# using fused AdamW: True
# compiling the model... (takes a ~minute)
# step 0: train loss 5.5931, val loss 5.5988
# iter 0: loss 5.5816, time 66923.16ms, mfu -100.00%
# iter 10: loss 3.6834, time 221.18ms, mfu 12.80%
# iter 20: loss 3.0492, time 221.73ms, mfu 12.80%
# iter 30: loss 2.5953, time 221.24ms, mfu 12.80%
# iter 40: loss 2.4416, time 221.62ms, mfu 12.79%
# iter 50: loss 2.3839, time 221.76ms, mfu 12.79%
# iter 60: loss 2.3612, time 221.39ms, mfu 12.79%
# iter 70: loss 2.3519, time 222.00ms, mfu 12.79%
# iter 80: loss 2.3304, time 221.91ms, mfu 12.78%
# iter 90: loss 2.3135, time 221.46ms, mfu 12.78%
# iter 100: loss 2.3046, time 221.83ms, mfu 12.78%
# iter 110: loss 2.2915, time 221.84ms, mfu 12.78%
# iter 120: loss 2.2716, time 221.96ms, mfu 12.78%
# iter 130: loss 2.2547, time 221.82ms, mfu 12.78%
# iter 140: loss 2.2298, time 221.93ms, mfu 12.77%
# iter 150: loss 2.1635, time 221.64ms, mfu 12.77%
# iter 2110: loss 1.0269, time 222.53ms, mfu 12.28%
# iter 2120: loss 0.9853, time 223.50ms, mfu 12.31%
# iter 2130: loss 0.9953, time 223.15ms, mfu 12.35%
# iter 2140: loss 0.9837, time 223.54ms, mfu 12.38%
# iter 2150: loss 1.0042, time 222.84ms, mfu 12.41%
# iter 2160: loss 0.9969, time 223.34ms, mfu 12.44%
# iter 2170: loss 0.9901, time 223.47ms, mfu 12.46%
# iter 2180: loss 0.9847, time 223.30ms, mfu 12.48%
# iter 2190: loss 0.9801, time 223.51ms, mfu 12.50%
# iter 2200: loss 0.9910, time 222.82ms, mfu 12.52%
# iter 2210: loss 0.9884, time 223.54ms, mfu 12.54%
# iter 2220: loss 0.9960, time 222.79ms, mfu 12.55%
# iter 2230: loss 0.9877, time 222.67ms, mfu 12.57%
# iter 2240: loss 0.9858, time 222.80ms, mfu 12.58%
# step 2250: train loss 0.8818, val loss 1.1766
# saving checkpoint to out-shakespeare-char
# iter 2250: loss 0.9741, time 30475.43ms, mfu 11.33%
# iter 2260: loss 0.9700, time 223.08ms, mfu 11.47%
# iter 2270: loss 0.9808, time 223.40ms, mfu 11.59%
# iter 2280: loss 0.9689, time 223.06ms, mfu 11.70%
# iter 2290: loss 0.9650, time 222.67ms, mfu 11.80%
# iter 2300: loss 0.9814, time 222.86ms, mfu 11.89%
# iter 2310: loss 0.9917, time 223.14ms, mfu 11.97%
# iter 2320: loss 0.9660, time 223.38ms, mfu 12.04%
# iter 2330: loss 0.9883, time 222.97ms, mfu 12.11%
# iter 2340: loss 0.9553, time 222.35ms, mfu 12.17%
# iter 2350: loss 0.9735, time 222.57ms, mfu 12.22%
# iter 2360: loss 0.9408, time 222.56ms, mfu 12.27%
# iter 2370: loss 0.9391, time 222.53ms, mfu 12.32%
# iter 2380: loss 0.9441, time 223.09ms, mfu 12.36%
# iter 2390: loss 0.9729, time 222.79ms, mfu 12.39%
# iter 2400: loss 0.9697, time 222.80ms, mfu 12.42%
# ^C
# Process ForkProcess-28:
# Process ForkProcess-21:
# Process ForkProcess-32:
# Process ForkProcess-25:
# Process ForkProcess-23:
# Process ForkProcess-18:
# Process ForkProcess-31:
# Process ForkProcess-29:
# Process ForkProcess-24:
# Process ForkProcess-30:
# Process ForkProcess-19:
# Process ForkProcess-11:
# Process ForkProcess-26:
# Process ForkProcess-20:
# Process ForkProcess-27:
# Process ForkProcess-22:
# Process ForkProcess-14:
# Process ForkProcess-13:
# Process ForkProcess-17:
# Process ForkProcess-5:
# Process ForkProcess-15:
# Process ForkProcess-8:
# Process ForkProcess-10:
# Process ForkProcess-9:
# Process ForkProcess-7:
# Process ForkProcess-4:
# Process ForkProcess-1:
# Process ForkProcess-2:
# Process ForkProcess-6:
# Process ForkProcess-12:
# Process ForkProcess-16:
# Process ForkProcess-3:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 103, in get
#     res = self._recv_bytes()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/workspace/nanoGPT/train.py", line 323, in <module>
#     lossf = loss.item() * gradient_accumulation_steps
# KeyboardInterrupt

# %%
! cd nanoGPT && python sample.py --out_dir=out-shakespeare-char
# Out:
# Overriding: out_dir = out-shakespeare-char
# number of parameters: 19.29M
# Loading meta from data/shakespeare_char/meta.pkl...
#
# - Ngay từ đầu thằng Tiểu Long có tiền lại không?
# - Không.
# - Ừ! Ngay cả tao cũng không biết đâu!
# Một lần nữa, Tiểu Long và Quý ròm sực nhớ ra cái sự "ngài pháp sư" của mình. Nhưng rồi có cảm giác như là khác nào khá ngửa nên Tiểu Long và Quý ròm lại đúng lúc nãy. Hai đứa này chỉ có Tiểu
# Long là hai đứa tiến về vô nhà luôn. Chỉ có thằng Quý ròm là nghi ngờ, chỉ khoái không được mà
# còn đau khổ thân cho hai đứa con gái lại thốt ra lằng nhằng lằn thằng bạn nó nhìn mình. Nhưng nếu
# trông nó nghe nó thì
# ---------------
#
# - Anh đừng lo! Anh là cướp gì thế! Chúng sẽ trở về nhà!
# Nhỏ Hạnh nhíu mày:
# - Em muốn kể chuyện đó thì em cũng phải lo lắng. Nhưng chính chị là chúng?
# Nhỏ Hạnh chưa kịp đáp thì nhỏ Hạnh đã nhanh chóng phát hiện ra không đứt mình bị lo lắng trong đầu. Nó hỏi sang chuyện khác:
# - Em muốn trả lời câu thơ lên đầy bằng cái gì hở Mạnh?
# - Không! - Nhỏ Hạnh lắc đầu - Nhưng em nghe lõm bõm cái gì chưa? Quý ròm nhún vai:
# - Thì em đã nói rồi! Tôi chỉ muốn nói cho tụi mình dẫn các bạn em biết hiểu rồi!
# - Chưa
# ---------------
#
# - Tối nay tao sẽ hóa ra những gì? - Cuối cùng, thằng Lâm day qua Tần lia lịa, mặt đỏ gay.
# - Ờ.
# - Thế sao lần này mày hỏi cách nào?
# - Tao hỏi một điều không đúng sao?
# - Ừ.
# - Cách gì? - Tần chưng hửng.
# - Nhưng cách gì?
# - Cách gì?
# - Cách gì?
# - Hôm nay tao không đến nỗi này! - Tần gật đầu - Tao đã nói rồi, đâu có biết thằng Tần nói trước. Nói ra điều đó, nó sẵn sàng gật gù ra vẻ hiểu biết:
# - Thì đúng ra.
# - Thì mình hiểu rồi! - Lâm chép miệng - Tao thấy gì thằng ghẻ cũng chẳng những cuốn tập vở nghệ
# ---------------
#
# Nhưng Quý ròm chỉ buột miệng hỏi thế, chỉ nói cho chắc chắn ra cái tật. Nó không biết Tiểu Long đã thót bụng lại là “thằng thỏ đế” ngay
# tắp lự.
# Một lát, nó bỗng lập tức bỏ chạy lại, thì thầm:
# - Không được đâu! Không được đâu! Cái tật đó của Quý ròm khiến Tiểu Long phải hỏi thẳng.
# Vẻ mặt thân thiện của Tiểu Long khiến ông anh ngẩn tò te không kém:
# - Em không được đâu! Thằng Quý ròm đâu nói là gì cho rồi, đi theo anh tao nghe đây nè! Tiểu Long liếm môi:
# - Mày về đi!
# - Biết chứ sao! - Quý ròm hừ mũ
# ---------------
#
# - Tao cũng nghĩ như mày! - Quý ròm nhún vai - Chắc chắn là tao vô thật!
# Lời giải thích của Quý ròm khiến Tiểu Long giật thót. Nó chẳng buồn để ý đến
# chuyện này. Nó nhìn sững bạn, thở dài:
# - Nó là nó thật hở dài thật hả? Quý ròm nhún vai:
# - Thật chứ sao?
# - Thật thì nó cũng không thật hở?
# - Thật! Đơn giản chính nó chưa hiểu tại sao thằng Lâm lại hối hả mày không nỡ?
# - Chưa hiểu tại sao thằng lâm vào đây nó không đến nỗi nào cả! - Tiểu Long nghiến răng trèo trẹo - Lúc đó tao chỉ nghĩ những chuyện đ
# ---------------
#
# - À, chắc là ăn nói lung tung thế này sao mà lụng lút chiếc mâm vào chiếc khăn hay chiếc thùng sắt của ông sẽ trở lại thêm vài chiếc giày để cho hai người một món quà cho bất cứ ai đột ngột ra đó là chiếc máy ảnh ly sữa nhỉ?
# - Chuyện đó thì sao?
# Nhỏ Hạnh thản nhiên:
# - Mình sẽ đưa ổng đi! Mình sẽ đưa ổng một chiếc máy ảnh trước khi vào thẩu thuốc trên ti-vi như thế!
# - Đúng rồi! - Nhỏ Hạnh lắc đầu - Tụi mình đã đưa ổng đi rồi đó! Tôi sẽ đi vào chợ rồi!
# Nghe Quý ròm nói vậy, Tiểu Long bất thần phán
# ---------------
#
# - Anh đừng có tiết lộ bài toán như thế! – Miệng nói bí hiểm – Mình đã nói rồi còn bài toán của mình là thằng nhóc này không tin!
# - Thì được! – Minh Vương nheo nheo mắt – Nhưng em vẫn không hé môi!
# - Thì ra thế! – Minh Vương thở phào – Ngay cả tình em cũng đã biết nó đứng trước lên bảng thì em chẳng biết làm. Chứng minh Vương định nói thế thôi!
# - Tao không tin! – Đỗ Lễ nhún vai – Nếu không phải tiết lộ chuyện để cho mình tha hồ tuần trước, nó lại giảng giải thích được điểm thể chuyện trêu chọc gi
# ---------------
#
# Văn Châu tận mắt nhìn tôi. Trong chung kế hoạch nháy mắt, nó cảm thấy khó nhớ không ai để ý đến chuyện đó. Nó liếc Quý ròm, há hốc miệng hỏi:
# - Tôi không cho tụi này ra chuyện đó nữa hả?
# - Không ngoài nào cả! - Quý ròm cắn môi - Tôi chỉ đây mới là tháy đó thôi!
# - Thế nào? - Văn Châu hỏi lại.
# - Thái độ cũng chả có gì đáng nghi ngờ! - Quý ròm nhún vai - Tụi này dựa vào nhà chơi với một băng ngón tay thôi!
# Nhỏ Hạnh nhíu mày:
# - Nhưng bọn này không phải là bọn ăn thịt người của chúng! Quý ròm nghiến
# ---------------
#
# Chương 4/10
# Chiều nào mua tập của Quý ròm, Tiểu Long đã đi theo.
# Nhưng dù cái khoảng tám triệu đó để thi vào bàn tay nó để đề phòng thằng ròm trả lời thay đổi thái độ kho báu và nhất là thằng ròm đã không biết phải làm sao.
# Và trong khi Tiểu Long thoáng mắt đã dừng lại ở đó, nó đột nhiên thấy một vố đau khổ lạnh và buồn bã chạy vù ra cửa.
# Quý ròm chưa kịp lên tiếng thì Tiểu Long đã gọi giật:
# - Bỏ về phòng học của tao được đấy! Ðâu có là đi theo!
# - Đi theo đại cho mày thì phải theo dõi! - Tiểu Lo
# ---------------
#
# Anh Tuấn đáp thay anh Tú đang làm một cách nhao nhao:
# - Lúc nãy em thanh niên ỏng bỏ tỉnh táo kia mà!
# - Lúc nãy em thấy chúng ta có đang nấp ở đằng kia! – Anh Tuấn nãy giờ vẫn cố giữ yên tâm – Chúng ta mua tông nhà thủ đến đây!
# Anh Tú mỉm cười nhìn Quý ròm, răng cười hì
# hì:
# - Tao mua làm gì vậy?
# - Chỉ đang thế thôi! – Anh Tuấn trầm ngâm – Chúng ta phải đi giữa nhà nhỏ Hạnh nhưng tìm cách gây gổ thân thương!
# - Ðừng có nói bậy! – Anh Tú bĩu môi – Thành nhà thủ lĩnh mới trẻ được giữ “đánh nhau đâu”
# ---------------
